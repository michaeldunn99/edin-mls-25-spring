# %% [markdown]
# ## 🚀 Compare speed of Distance Functions 🚀

# %%
# %matplotlib inline
import matplotlib
matplotlib.use("module://matplotlib_inline.backend_inline")

# %%
from task import (
    distance_l2_CUPY,
    distance_l2_triton,
    distance_l2_cpu,
    distance_manhattan_CUPY,
    distance_l1_triton,
    distance_manhattan_cpu,
    distance_cosine_CUPY,
    distance_cosine_triton,
    distance_cosine_cpu,
    distance_dot_CUPY,
    distance_dot_triton,
    distance_dot_cpu,
    test_distance_wrapper
)
import numpy as np
import seaborn as sns

# %%
np.random.seed(1967)
vector_sizes = [2**i for i in range(1, 27)]
X_array = [np.random.rand(size,) for size in vector_sizes]
Y_array = [np.random.rand(size,) for size in vector_sizes]

# %%
functions = {
    "L2": [
        distance_l2_CUPY,
        distance_l2_triton,
        distance_l2_cpu,
    ],
    "L1": [
        distance_manhattan_CUPY,
        distance_l1_triton,
        distance_manhattan_cpu,
    ],
    "Cosine": [
        distance_cosine_CUPY,
        distance_cosine_triton,
        distance_cosine_cpu,
    ],
    "Dot Product": [
        distance_dot_CUPY,
        distance_dot_triton,
        distance_dot_cpu,
    ],
}

# %%
results_list = {}
for function_type, function_list in functions.items():
    results_list[function_type]= []
    for function in function_list:
        inner_results_item = []
        for i in range(len(vector_sizes)):
            size = vector_sizes[i]
            X = X_array[i]
            Y = Y_array[i]
            result = test_distance_wrapper(function, X, Y, repeat=25)
            inner_results_item.append(result[2])
        results_item = {function.__name__: inner_results_item}
        results_list[function_type].append(results_item)
for function_type, function_list in results_list.items():
    print(function_type)
    for function in function_list:
        for function_name, result in function.items():
            print(f"{function_name}: {result}")
    print()
# Out:
# Distance Function: distance_l2_CUPY, Result: 0.7299734048837618, Time: 0.235977 milliseconds.
# Distance Function: distance_l2_CUPY, Result: 1.1509329570981803, Time: 0.204992 milliseconds.
# Distance Function: distance_l2_CUPY, Result: 1.0331167196945064, Time: 0.207653 milliseconds.
# Distance Function: distance_l2_CUPY, Result: 1.5700850189007949, Time: 0.204382 milliseconds.
# Distance Function: distance_l2_CUPY, Result: 2.192638331385474, Time: 0.200005 milliseconds.
# Distance Function: distance_l2_CUPY, Result: 2.8867480608128844, Time: 0.203247 milliseconds.
# Distance Function: distance_l2_CUPY, Result: 4.927927196020329, Time: 0.200586 milliseconds.
# Distance Function: distance_l2_CUPY, Result: 7.0576198843220395, Time: 0.200624 milliseconds.
# Distance Function: distance_l2_CUPY, Result: 9.01344958394972, Time: 0.203943 milliseconds.
# Distance Function: distance_l2_CUPY, Result: 12.917371987493711, Time: 0.205364 milliseconds.
# Distance Function: distance_l2_CUPY, Result: 18.32031778406253, Time: 0.213118 milliseconds.
# Distance Function: distance_l2_CUPY, Result: 26.076799480012458, Time: 0.227032 milliseconds.
# Distance Function: distance_l2_CUPY, Result: 36.76463608482935, Time: 0.236979 milliseconds.
# Distance Function: distance_l2_CUPY, Result: 52.407919077917796, Time: 0.276794 milliseconds.
# Distance Function: distance_l2_CUPY, Result: 73.62420746628328, Time: 0.285692 milliseconds.
# Distance Function: distance_l2_CUPY, Result: 104.06217137466935, Time: 0.350761 milliseconds.
# Distance Function: distance_l2_CUPY, Result: 147.5441978167676, Time: 0.494156 milliseconds.
# Distance Function: distance_l2_CUPY, Result: 208.74624798409417, Time: 0.699205 milliseconds.
# Distance Function: distance_l2_CUPY, Result: 295.8559900578201, Time: 2.047358 milliseconds.
# Distance Function: distance_l2_CUPY, Result: 418.1537343829407, Time: 3.932524 milliseconds.
# Distance Function: distance_l2_CUPY, Result: 591.2272468739225, Time: 7.954931 milliseconds.
# Distance Function: distance_l2_CUPY, Result: 836.0475352007672, Time: 16.326265 milliseconds.
# Distance Function: distance_l2_CUPY, Result: 1182.4062496549857, Time: 32.349072 milliseconds.
# Distance Function: distance_l2_CUPY, Result: 1672.5321777276927, Time: 64.954729 milliseconds.
# Distance Function: distance_l2_CUPY, Result: 2364.8372191688372, Time: 129.847307 milliseconds.
# Distance Function: distance_l2_CUPY, Result: 3344.5624312199643, Time: 256.676435 milliseconds.
# Distance Function: distance_l2_triton, Result: 0.7299734354019165, Time: 0.223999 milliseconds.
# Distance Function: distance_l2_triton, Result: 1.150933027267456, Time: 0.217886 milliseconds.
# Distance Function: distance_l2_triton, Result: 1.0331166982650757, Time: 0.209246 milliseconds.
# Distance Function: distance_l2_triton, Result: 1.570085048675537, Time: 0.208845 milliseconds.
# Distance Function: distance_l2_triton, Result: 2.192638397216797, Time: 0.204763 milliseconds.
# Distance Function: distance_l2_triton, Result: 2.8867480754852295, Time: 0.208044 milliseconds.
# Distance Function: distance_l2_triton, Result: 4.927927017211914, Time: 0.205679 milliseconds.
# Distance Function: distance_l2_triton, Result: 7.057620048522949, Time: 0.210400 milliseconds.
# Distance Function: distance_l2_triton, Result: 9.013449668884277, Time: 0.209398 milliseconds.
# Distance Function: distance_l2_triton, Result: 12.917372703552246, Time: 0.215092 milliseconds.
# Distance Function: distance_l2_triton, Result: 18.3203182220459, Time: 0.218801 milliseconds.
# Distance Function: distance_l2_triton, Result: 26.076799392700195, Time: 0.234556 milliseconds.
# Distance Function: distance_l2_triton, Result: 36.7646369934082, Time: 0.262928 milliseconds.
# Distance Function: distance_l2_triton, Result: 52.40791702270508, Time: 0.308876 milliseconds.
# Distance Function: distance_l2_triton, Result: 73.62421417236328, Time: 0.425367 milliseconds.
# Distance Function: distance_l2_triton, Result: 104.06217193603516, Time: 0.559883 milliseconds.
# Distance Function: distance_l2_triton, Result: 147.544189453125, Time: 0.866365 milliseconds.
# Distance Function: distance_l2_triton, Result: 208.74624633789062, Time: 1.303568 milliseconds.
# Distance Function: distance_l2_triton, Result: 295.8559875488281, Time: 2.130089 milliseconds.
# Distance Function: distance_l2_triton, Result: 418.15374755859375, Time: 3.865852 milliseconds.
# Distance Function: distance_l2_triton, Result: 591.2272338867188, Time: 7.662344 milliseconds.
# Distance Function: distance_l2_triton, Result: 836.0475463867188, Time: 15.085001 milliseconds.
# Distance Function: distance_l2_triton, Result: 1182.40625, Time: 29.407759 milliseconds.
# Distance Function: distance_l2_triton, Result: 1672.5322265625, Time: 58.552799 milliseconds.
# Distance Function: distance_l2_triton, Result: 2364.837158203125, Time: 115.759773 milliseconds.
# Distance Function: distance_l2_triton, Result: 3344.5625, Time: 229.914494 milliseconds.
# Distance Function: distance_l2_cpu, Result: 0.7299734048837618, Time: 0.013428 milliseconds.
# Distance Function: distance_l2_cpu, Result: 1.1509329570981803, Time: 0.011177 milliseconds.
# Distance Function: distance_l2_cpu, Result: 1.0331167196945064, Time: 0.011091 milliseconds.
# Distance Function: distance_l2_cpu, Result: 1.5700850189007949, Time: 0.011854 milliseconds.
# Distance Function: distance_l2_cpu, Result: 2.192638331385474, Time: 0.011988 milliseconds.
# Distance Function: distance_l2_cpu, Result: 2.8867480608128844, Time: 0.011559 milliseconds.
# Distance Function: distance_l2_cpu, Result: 4.927927196020329, Time: 0.012712 milliseconds.
# Distance Function: distance_l2_cpu, Result: 7.0576198843220395, Time: 0.014200 milliseconds.
# Distance Function: distance_l2_cpu, Result: 9.01344958394972, Time: 0.015259 milliseconds.
# Distance Function: distance_l2_cpu, Result: 12.917371987493711, Time: 0.014639 milliseconds.
# Distance Function: distance_l2_cpu, Result: 18.32031778406253, Time: 0.015306 milliseconds.
# Distance Function: distance_l2_cpu, Result: 26.076799480012458, Time: 0.018024 milliseconds.
# Distance Function: distance_l2_cpu, Result: 36.76463608482935, Time: 0.024319 milliseconds.
# Distance Function: distance_l2_cpu, Result: 52.407919077917796, Time: 0.053787 milliseconds.
# Distance Function: distance_l2_cpu, Result: 73.62420746628328, Time: 0.080748 milliseconds.
# Distance Function: distance_l2_cpu, Result: 104.06217137466933, Time: 0.137186 milliseconds.
# Distance Function: distance_l2_cpu, Result: 147.54419781676762, Time: 0.231209 milliseconds.
# Distance Function: distance_l2_cpu, Result: 208.74624798409417, Time: 0.445356 milliseconds.
# Distance Function: distance_l2_cpu, Result: 295.85599005782007, Time: 0.768223 milliseconds.
# Distance Function: distance_l2_cpu, Result: 418.1537343829407, Time: 1.402636 milliseconds.
# Distance Function: distance_l2_cpu, Result: 591.2272468739225, Time: 3.255529 milliseconds.
# Distance Function: distance_l2_cpu, Result: 836.0475352007672, Time: 14.220505 milliseconds.
# Distance Function: distance_l2_cpu, Result: 1182.406249654986, Time: 30.477991 milliseconds.
# Distance Function: distance_l2_cpu, Result: 1672.5321777276934, Time: 61.939173 milliseconds.
# Distance Function: distance_l2_cpu, Result: 2364.8372191688377, Time: 126.134062 milliseconds.
# Distance Function: distance_l2_cpu, Result: 3344.562431219965, Time: 242.779007 milliseconds.
# Distance Function: distance_manhattan_CUPY, Result: 1.014396787629276, Time: 0.249958 milliseconds.
# Distance Function: distance_manhattan_CUPY, Result: 2.2511393758360487, Time: 0.220404 milliseconds.
# Distance Function: distance_manhattan_CUPY, Result: 2.1793360517343294, Time: 0.220652 milliseconds.
# Distance Function: distance_manhattan_CUPY, Result: 5.4780703824373465, Time: 0.219851 milliseconds.
# Distance Function: distance_manhattan_CUPY, Result: 9.891664044557071, Time: 0.219584 milliseconds.
# Distance Function: distance_manhattan_CUPY, Result: 18.32824321987353, Time: 0.220280 milliseconds.
# Distance Function: distance_manhattan_CUPY, Result: 45.70620963018273, Time: 0.222416 milliseconds.
# Distance Function: distance_manhattan_CUPY, Result: 92.80736869152929, Time: 0.224066 milliseconds.
# Distance Function: distance_manhattan_CUPY, Result: 163.83613640913066, Time: 0.225725 milliseconds.
# Distance Function: distance_manhattan_CUPY, Result: 336.24452407423445, Time: 0.228958 milliseconds.
# Distance Function: distance_manhattan_CUPY, Result: 674.2151812819518, Time: 0.235777 milliseconds.
# Distance Function: distance_manhattan_CUPY, Result: 1361.4465221322496, Time: 0.252333 milliseconds.
# Distance Function: distance_manhattan_CUPY, Result: 2703.924674412377, Time: 0.261497 milliseconds.
# Distance Function: distance_manhattan_CUPY, Result: 5474.213404048774, Time: 0.281172 milliseconds.
# Distance Function: distance_manhattan_CUPY, Result: 10872.26810820753, Time: 0.322590 milliseconds.
# Distance Function: distance_manhattan_CUPY, Result: 21724.293918143325, Time: 0.393543 milliseconds.
# Distance Function: distance_manhattan_CUPY, Result: 43610.26122371055, Time: 0.506964 milliseconds.
# Distance Function: distance_manhattan_CUPY, Result: 87252.24873040235, Time: 0.696878 milliseconds.
# Distance Function: distance_manhattan_CUPY, Result: 174885.81927474338, Time: 2.027311 milliseconds.
# Distance Function: distance_manhattan_CUPY, Result: 349639.3724587254, Time: 3.901644 milliseconds.
# Distance Function: distance_manhattan_CUPY, Result: 698979.9487164953, Time: 7.929935 milliseconds.
# Distance Function: distance_manhattan_CUPY, Result: 1397905.343627629, Time: 16.539097 milliseconds.
# Distance Function: distance_manhattan_CUPY, Result: 2796143.1440948714, Time: 32.671585 milliseconds.
# Distance Function: distance_manhattan_CUPY, Result: 5593978.272850302, Time: 64.432840 milliseconds.
# Distance Function: distance_manhattan_CUPY, Result: 11184940.921635542, Time: 129.022932 milliseconds.
# Distance Function: distance_manhattan_CUPY, Result: 22370931.77702857, Time: 256.964903 milliseconds.
# Distance Function: distance_l1_triton, Result: 1.0143967866897583, Time: 0.185585 milliseconds.
# Distance Function: distance_l1_triton, Result: 2.2511394023895264, Time: 0.182199 milliseconds.
# Distance Function: distance_l1_triton, Result: 2.1793360710144043, Time: 0.179691 milliseconds.
# Distance Function: distance_l1_triton, Result: 5.478070259094238, Time: 0.178719 milliseconds.
# Distance Function: distance_l1_triton, Result: 9.891664505004883, Time: 0.180054 milliseconds.
# Distance Function: distance_l1_triton, Result: 18.328243255615234, Time: 0.181065 milliseconds.
# Distance Function: distance_l1_triton, Result: 45.70621109008789, Time: 0.178118 milliseconds.
# Distance Function: distance_l1_triton, Result: 92.80736541748047, Time: 0.180311 milliseconds.
# Distance Function: distance_l1_triton, Result: 163.8361358642578, Time: 0.183849 milliseconds.
# Distance Function: distance_l1_triton, Result: 336.2445373535156, Time: 0.186968 milliseconds.
# Distance Function: distance_l1_triton, Result: 674.2152099609375, Time: 0.193148 milliseconds.
# Distance Function: distance_l1_triton, Result: 1361.446533203125, Time: 0.207300 milliseconds.
# Distance Function: distance_l1_triton, Result: 2703.9248046875, Time: 0.232000 milliseconds.
# Distance Function: distance_l1_triton, Result: 5474.2138671875, Time: 0.281992 milliseconds.
# Distance Function: distance_l1_triton, Result: 10872.267578125, Time: 0.369930 milliseconds.
# Distance Function: distance_l1_triton, Result: 21724.294921875, Time: 0.545311 milliseconds.
# Distance Function: distance_l1_triton, Result: 43610.26171875, Time: 0.854931 milliseconds.
# Distance Function: distance_l1_triton, Result: 87252.25, Time: 1.294813 milliseconds.
# Distance Function: distance_l1_triton, Result: 174885.8125, Time: 2.119513 milliseconds.
# Distance Function: distance_l1_triton, Result: 349639.375, Time: 3.788757 milliseconds.
# Distance Function: distance_l1_triton, Result: 698979.9375, Time: 7.375021 milliseconds.
# Distance Function: distance_l1_triton, Result: 1397905.375, Time: 14.859371 milliseconds.
# Distance Function: distance_l1_triton, Result: 2796143.25, Time: 29.512653 milliseconds.
# Distance Function: distance_l1_triton, Result: 5593978.0, Time: 58.276081 milliseconds.
# Distance Function: distance_l1_triton, Result: 11184940.0, Time: 115.369368 milliseconds.
# Distance Function: distance_l1_triton, Result: 22370932.0, Time: 230.419731 milliseconds.
# Distance Function: distance_manhattan_cpu, Result: 1.014396787629276, Time: 0.021639 milliseconds.
# Distance Function: distance_manhattan_cpu, Result: 2.2511393758360487, Time: 0.018425 milliseconds.
# Distance Function: distance_manhattan_cpu, Result: 2.1793360517343294, Time: 0.019445 milliseconds.
# Distance Function: distance_manhattan_cpu, Result: 5.478070382437346, Time: 0.018406 milliseconds.
# Distance Function: distance_manhattan_cpu, Result: 9.891664044557071, Time: 0.019169 milliseconds.
# Distance Function: distance_manhattan_cpu, Result: 18.328243219873535, Time: 0.018530 milliseconds.
# Distance Function: distance_manhattan_cpu, Result: 45.70620963018272, Time: 0.019274 milliseconds.
# Distance Function: distance_manhattan_cpu, Result: 92.80736869152928, Time: 0.019178 milliseconds.
# Distance Function: distance_manhattan_cpu, Result: 163.8361364091307, Time: 0.020189 milliseconds.
# Distance Function: distance_manhattan_cpu, Result: 336.2445240742345, Time: 0.021725 milliseconds.
# Distance Function: distance_manhattan_cpu, Result: 674.2151812819518, Time: 0.021725 milliseconds.
# Distance Function: distance_manhattan_cpu, Result: 1361.4465221322496, Time: 0.024290 milliseconds.
# Distance Function: distance_manhattan_cpu, Result: 2703.9246744123766, Time: 0.029459 milliseconds.
# Distance Function: distance_manhattan_cpu, Result: 5474.213404048774, Time: 0.044756 milliseconds.
# Distance Function: distance_manhattan_cpu, Result: 10872.26810820753, Time: 0.084200 milliseconds.
# Distance Function: distance_manhattan_cpu, Result: 21724.293918143325, Time: 0.169525 milliseconds.
# Distance Function: distance_manhattan_cpu, Result: 43610.26122371055, Time: 0.329523 milliseconds.
# Distance Function: distance_manhattan_cpu, Result: 87252.24873040234, Time: 0.625982 milliseconds.
# Distance Function: distance_manhattan_cpu, Result: 174885.8192747434, Time: 1.184797 milliseconds.
# Distance Function: distance_manhattan_cpu, Result: 349639.3724587254, Time: 2.686548 milliseconds.
# Distance Function: distance_manhattan_cpu, Result: 698979.9487164955, Time: 13.733854 milliseconds.
# Distance Function: distance_manhattan_cpu, Result: 1397905.3436276284, Time: 27.173386 milliseconds.
# Distance Function: distance_manhattan_cpu, Result: 2796143.144094865, Time: 56.280127 milliseconds.
# Distance Function: distance_manhattan_cpu, Result: 5593978.272850313, Time: 113.598433 milliseconds.
# Distance Function: distance_manhattan_cpu, Result: 11184940.921635542, Time: 228.563385 milliseconds.
# Distance Function: distance_manhattan_cpu, Result: 22370931.77702852, Time: 455.769653 milliseconds.
# Distance Function: distance_cosine_CUPY, Result: 0.03240518565723194, Time: 0.359735 milliseconds.
# Distance Function: distance_cosine_CUPY, Result: 0.31284659252409486, Time: 0.343609 milliseconds.
# Distance Function: distance_cosine_CUPY, Result: 0.20661304165247152, Time: 0.341749 milliseconds.
# Distance Function: distance_cosine_CUPY, Result: 0.20172083897518445, Time: 0.340738 milliseconds.
# Distance Function: distance_cosine_CUPY, Result: 0.2225308087345237, Time: 0.345850 milliseconds.
# Distance Function: distance_cosine_CUPY, Result: 0.19254010597097226, Time: 0.344534 milliseconds.
# Distance Function: distance_cosine_CUPY, Result: 0.28101724466434297, Time: 0.340538 milliseconds.
# Distance Function: distance_cosine_CUPY, Result: 0.3067412594258935, Time: 0.341797 milliseconds.
# Distance Function: distance_cosine_CUPY, Result: 0.2388140722778015, Time: 0.344467 milliseconds.
# Distance Function: distance_cosine_CUPY, Result: 0.23567117090862266, Time: 0.343657 milliseconds.
# Distance Function: distance_cosine_CUPY, Result: 0.24723336790643824, Time: 0.351801 milliseconds.
# Distance Function: distance_cosine_CUPY, Result: 0.24881695003069515, Time: 0.377741 milliseconds.
# Distance Function: distance_cosine_CUPY, Result: 0.24800321927740532, Time: 0.385485 milliseconds.
# Distance Function: distance_cosine_CUPY, Result: 0.2509472336305034, Time: 0.416698 milliseconds.
# Distance Function: distance_cosine_CUPY, Result: 0.24790143372846662, Time: 0.444698 milliseconds.
# Distance Function: distance_cosine_CUPY, Result: 0.24656475331321526, Time: 0.500660 milliseconds.
# Distance Function: distance_cosine_CUPY, Result: 0.24881816161350534, Time: 0.631561 milliseconds.
# Distance Function: distance_cosine_CUPY, Result: 0.24910937572127434, Time: 0.823030 milliseconds.
# Distance Function: distance_cosine_CUPY, Result: 0.2502513983840907, Time: 2.063856 milliseconds.
# Distance Function: distance_cosine_CUPY, Result: 0.250050743669472, Time: 3.970690 milliseconds.
# Distance Function: distance_cosine_CUPY, Result: 0.24993376860330596, Time: 8.138132 milliseconds.
# Distance Function: distance_cosine_CUPY, Result: 0.24992551018759168, Time: 16.549368 milliseconds.
# Distance Function: distance_cosine_CUPY, Result: 0.25000625265982623, Time: 33.298674 milliseconds.
# Distance Function: distance_cosine_CUPY, Result: 0.2502077748881969, Time: 66.961012 milliseconds.
# Distance Function: distance_cosine_CUPY, Result: 0.24996744841606133, Time: 133.601255 milliseconds.
# Distance Function: distance_cosine_CUPY, Result: 0.2500285223128368, Time: 265.872097 milliseconds.
# Distance Function: distance_cosine_triton, Result: 0.03240513801574707, Time: 0.320396 milliseconds.
# Distance Function: distance_cosine_triton, Result: 0.31284666061401367, Time: 0.312061 milliseconds.
# Distance Function: distance_cosine_triton, Result: 0.20661306381225586, Time: 0.307961 milliseconds.
# Distance Function: distance_cosine_triton, Result: 0.20172077417373657, Time: 0.308523 milliseconds.
# Distance Function: distance_cosine_triton, Result: 0.22253084182739258, Time: 0.309515 milliseconds.
# Distance Function: distance_cosine_triton, Result: 0.19254016876220703, Time: 0.306778 milliseconds.
# Distance Function: distance_cosine_triton, Result: 0.2810172438621521, Time: 0.306902 milliseconds.
# Distance Function: distance_cosine_triton, Result: 0.30674123764038086, Time: 0.310144 milliseconds.
# Distance Function: distance_cosine_triton, Result: 0.23881399631500244, Time: 0.308123 milliseconds.
# Distance Function: distance_cosine_triton, Result: 0.23567116260528564, Time: 0.317020 milliseconds.
# Distance Function: distance_cosine_triton, Result: 0.2472333312034607, Time: 0.322056 milliseconds.
# Distance Function: distance_cosine_triton, Result: 0.2488168478012085, Time: 0.332108 milliseconds.
# Distance Function: distance_cosine_triton, Result: 0.2480033040046692, Time: 0.358877 milliseconds.
# Distance Function: distance_cosine_triton, Result: 0.25094717741012573, Time: 0.410261 milliseconds.
# Distance Function: distance_cosine_triton, Result: 0.24790143966674805, Time: 0.496511 milliseconds.
# Distance Function: distance_cosine_triton, Result: 0.2465648055076599, Time: 0.656853 milliseconds.
# Distance Function: distance_cosine_triton, Result: 0.24881821870803833, Time: 0.983391 milliseconds.
# Distance Function: distance_cosine_triton, Result: 0.24910932779312134, Time: 1.454639 milliseconds.
# Distance Function: distance_cosine_triton, Result: 0.2502514123916626, Time: 2.254906 milliseconds.
# Distance Function: distance_cosine_triton, Result: 0.25005072355270386, Time: 3.952694 milliseconds.
# Distance Function: distance_cosine_triton, Result: 0.24993371963500977, Time: 7.699938 milliseconds.
# Distance Function: distance_cosine_triton, Result: 0.24992555379867554, Time: 15.025282 milliseconds.
# Distance Function: distance_cosine_triton, Result: 0.2500063180923462, Time: 29.917803 milliseconds.
# Distance Function: distance_cosine_triton, Result: 0.25020772218704224, Time: 58.636131 milliseconds.
# Distance Function: distance_cosine_triton, Result: 0.2499675154685974, Time: 115.897684 milliseconds.
# Distance Function: distance_cosine_triton, Result: 0.2500285506248474, Time: 230.202789 milliseconds.
# Distance Function: distance_cosine_cpu, Result: 0.03240518565723194, Time: 0.020418 milliseconds.
# Distance Function: distance_cosine_cpu, Result: 0.31284659252409475, Time: 0.019646 milliseconds.
# Distance Function: distance_cosine_cpu, Result: 0.20661304165247163, Time: 0.018330 milliseconds.
# Distance Function: distance_cosine_cpu, Result: 0.20172083897518456, Time: 0.019207 milliseconds.
# Distance Function: distance_cosine_cpu, Result: 0.2225308087345237, Time: 0.019884 milliseconds.
# Distance Function: distance_cosine_cpu, Result: 0.19254010597097193, Time: 0.019760 milliseconds.
# Distance Function: distance_cosine_cpu, Result: 0.28101724466434297, Time: 0.020533 milliseconds.
# Distance Function: distance_cosine_cpu, Result: 0.3067412594258936, Time: 0.019932 milliseconds.
# Distance Function: distance_cosine_cpu, Result: 0.2388140722778015, Time: 0.021410 milliseconds.
# Distance Function: distance_cosine_cpu, Result: 0.23567117090862255, Time: 0.021486 milliseconds.
# Distance Function: distance_cosine_cpu, Result: 0.24723336790643802, Time: 0.023804 milliseconds.
# Distance Function: distance_cosine_cpu, Result: 0.24881695003069504, Time: 0.025911 milliseconds.
# Distance Function: distance_cosine_cpu, Result: 0.24800321927740543, Time: 0.036335 milliseconds.
# Distance Function: distance_cosine_cpu, Result: 0.25094723363050364, Time: 0.063848 milliseconds.
# Distance Function: distance_cosine_cpu, Result: 0.24790143372846685, Time: 0.090427 milliseconds.
# Distance Function: distance_cosine_cpu, Result: 0.24656475331321526, Time: 0.158768 milliseconds.
# Distance Function: distance_cosine_cpu, Result: 0.24881816161350556, Time: 0.267601 milliseconds.
# Distance Function: distance_cosine_cpu, Result: 0.24910937572127445, Time: 0.502882 milliseconds.
# Distance Function: distance_cosine_cpu, Result: 0.2502513983840906, Time: 0.969515 milliseconds.
# Distance Function: distance_cosine_cpu, Result: 0.2500507436694718, Time: 1.927347 milliseconds.
# Distance Function: distance_cosine_cpu, Result: 0.2499337686033054, Time: 5.173893 milliseconds.
# Distance Function: distance_cosine_cpu, Result: 0.24992551018759235, Time: 18.527327 milliseconds.
# Distance Function: distance_cosine_cpu, Result: 0.25000625265982623, Time: 39.932623 milliseconds.
# Distance Function: distance_cosine_cpu, Result: 0.2502077748881977, Time: 76.128931 milliseconds.
# Distance Function: distance_cosine_cpu, Result: 0.24996744841605945, Time: 151.446800 milliseconds.
# Distance Function: distance_cosine_cpu, Result: 0.250028522312837, Time: 294.274616 milliseconds.
# Distance Function: distance_dot_CUPY, Result: 0.18123667744296762, Time: 0.223570 milliseconds.
# Distance Function: distance_dot_CUPY, Result: 1.0977187638739294, Time: 0.200853 milliseconds.
# Distance Function: distance_dot_CUPY, Result: 2.0085842948240336, Time: 0.196209 milliseconds.
# Distance Function: distance_dot_CUPY, Result: 4.872777334919508, Time: 0.195675 milliseconds.
# Distance Function: distance_dot_CUPY, Result: 7.982553386303176, Time: 0.200853 milliseconds.
# Distance Function: distance_dot_CUPY, Result: 17.4689922580994, Time: 0.202332 milliseconds.
# Distance Function: distance_dot_CUPY, Result: 31.04686135270606, Time: 0.199680 milliseconds.
# Distance Function: distance_dot_CUPY, Result: 56.09348804263791, Time: 0.198727 milliseconds.
# Distance Function: distance_dot_CUPY, Result: 128.50329601505575, Time: 0.268631 milliseconds.
# Distance Function: distance_dot_CUPY, Result: 269.8610843457602, Time: 0.224323 milliseconds.
# Distance Function: distance_dot_CUPY, Result: 509.98148888734687, Time: 0.212870 milliseconds.
# Distance Function: distance_dot_CUPY, Result: 1026.3761136337935, Time: 0.224257 milliseconds.
# Distance Function: distance_dot_CUPY, Result: 2049.2203008557417, Time: 0.235729 milliseconds.
# Distance Function: distance_dot_CUPY, Result: 4099.11418683936, Time: 0.257463 milliseconds.
# Distance Function: distance_dot_CUPY, Result: 8222.525257986925, Time: 0.283480 milliseconds.
# Distance Function: distance_dot_CUPY, Result: 16544.930424648872, Time: 0.357227 milliseconds.
# Distance Function: distance_dot_CUPY, Result: 32860.72863735343, Time: 0.511160 milliseconds.
# Distance Function: distance_dot_CUPY, Result: 65674.07480929165, Time: 0.735769 milliseconds.
# Distance Function: distance_dot_CUPY, Result: 131120.28621619096, Time: 2.036009 milliseconds.
# Distance Function: distance_dot_CUPY, Result: 262206.92846575857, Time: 3.861475 milliseconds.
# Distance Function: distance_dot_CUPY, Result: 524509.7422152075, Time: 7.876091 milliseconds.
# Distance Function: distance_dot_CUPY, Result: 1048879.7860910515, Time: 16.079655 milliseconds.
# Distance Function: distance_dot_CUPY, Result: 2097055.8872213867, Time: 31.681738 milliseconds.
# Distance Function: distance_dot_CUPY, Result: 4191399.8604343887, Time: 63.568735 milliseconds.
# Distance Function: distance_dot_CUPY, Result: 8390139.120891985, Time: 126.810503 milliseconds.
# Distance Function: distance_dot_CUPY, Result: 16776594.64150708, Time: 252.363939 milliseconds.
# Distance Function: distance_dot_triton, Result: -0.18123668432235718, Time: 0.209942 milliseconds.
# Distance Function: distance_dot_triton, Result: -1.0977187156677246, Time: 0.196486 milliseconds.
# Distance Function: distance_dot_triton, Result: -2.0085842609405518, Time: 0.197344 milliseconds.
# Distance Function: distance_dot_triton, Result: -4.872777462005615, Time: 0.197363 milliseconds.
# Distance Function: distance_dot_triton, Result: -7.982553482055664, Time: 0.198345 milliseconds.
# Distance Function: distance_dot_triton, Result: -17.468992233276367, Time: 0.196190 milliseconds.
# Distance Function: distance_dot_triton, Result: -31.04686164855957, Time: 0.198421 milliseconds.
# Distance Function: distance_dot_triton, Result: -56.09348678588867, Time: 0.198307 milliseconds.
# Distance Function: distance_dot_triton, Result: -128.5032958984375, Time: 0.207090 milliseconds.
# Distance Function: distance_dot_triton, Result: -269.861083984375, Time: 0.206528 milliseconds.
# Distance Function: distance_dot_triton, Result: -509.98150634765625, Time: 0.213232 milliseconds.
# Distance Function: distance_dot_triton, Result: -1026.376220703125, Time: 0.225954 milliseconds.
# Distance Function: distance_dot_triton, Result: -2049.22021484375, Time: 0.251417 milliseconds.
# Distance Function: distance_dot_triton, Result: -4099.1142578125, Time: 0.298710 milliseconds.
# Distance Function: distance_dot_triton, Result: -8222.525390625, Time: 0.388355 milliseconds.
# Distance Function: distance_dot_triton, Result: -16544.9296875, Time: 0.557585 milliseconds.
# Distance Function: distance_dot_triton, Result: -32860.7265625, Time: 0.890017 milliseconds.
# Distance Function: distance_dot_triton, Result: -65674.078125, Time: 1.381178 milliseconds.
# Distance Function: distance_dot_triton, Result: -131120.28125, Time: 2.146120 milliseconds.
# Distance Function: distance_dot_triton, Result: -262206.9375, Time: 3.802681 milliseconds.
# Distance Function: distance_dot_triton, Result: -524509.75, Time: 7.365513 milliseconds.
# Distance Function: distance_dot_triton, Result: -1048879.75, Time: 14.941225 milliseconds.
# Distance Function: distance_dot_triton, Result: -2097055.875, Time: 29.375954 milliseconds.
# Distance Function: distance_dot_triton, Result: -4191400.0, Time: 58.082371 milliseconds.
# Distance Function: distance_dot_triton, Result: -8390138.0, Time: 115.470095 milliseconds.
# Distance Function: distance_dot_triton, Result: -16776594.0, Time: 230.367670 milliseconds.
# Distance Function: distance_dot_cpu, Result: -0.18123667744296762, Time: 0.017357 milliseconds.
# Distance Function: distance_dot_cpu, Result: -1.0977187638739294, Time: 0.017643 milliseconds.
# Distance Function: distance_dot_cpu, Result: -2.0085842948240336, Time: 0.016670 milliseconds.
# Distance Function: distance_dot_cpu, Result: -4.872777334919507, Time: 0.017567 milliseconds.
# Distance Function: distance_dot_cpu, Result: -7.982553386303177, Time: 0.016699 milliseconds.
# Distance Function: distance_dot_cpu, Result: -17.468992258099405, Time: 0.017385 milliseconds.
# Distance Function: distance_dot_cpu, Result: -31.04686135270606, Time: 0.016861 milliseconds.
# Distance Function: distance_dot_cpu, Result: -56.0934880426379, Time: 0.017519 milliseconds.
# Distance Function: distance_dot_cpu, Result: -128.50329601505575, Time: 0.024405 milliseconds.
# Distance Function: distance_dot_cpu, Result: -269.8610843457602, Time: 0.014963 milliseconds.
# Distance Function: distance_dot_cpu, Result: -509.981488887347, Time: 0.014038 milliseconds.
# Distance Function: distance_dot_cpu, Result: -1026.3761136337935, Time: 0.016432 milliseconds.
# Distance Function: distance_dot_cpu, Result: -2049.2203008557417, Time: 0.019274 milliseconds.
# Distance Function: distance_dot_cpu, Result: -4099.11418683936, Time: 0.029240 milliseconds.
# Distance Function: distance_dot_cpu, Result: -8222.525257986923, Time: 0.047750 milliseconds.
# Distance Function: distance_dot_cpu, Result: -16544.930424648872, Time: 0.103245 milliseconds.
# Distance Function: distance_dot_cpu, Result: -32860.72863735342, Time: 0.215397 milliseconds.
# Distance Function: distance_dot_cpu, Result: -65674.07480929165, Time: 0.414648 milliseconds.
# Distance Function: distance_dot_cpu, Result: -131120.286216191, Time: 0.797853 milliseconds.
# Distance Function: distance_dot_cpu, Result: -262206.9284657586, Time: 1.690521 milliseconds.
# Distance Function: distance_dot_cpu, Result: -524509.742215208, Time: 4.670973 milliseconds.
# Distance Function: distance_dot_cpu, Result: -1048879.7860910506, Time: 15.385609 milliseconds.
# Distance Function: distance_dot_cpu, Result: -2097055.8872213867, Time: 31.768970 milliseconds.
# Distance Function: distance_dot_cpu, Result: -4191399.8604343846, Time: 67.064915 milliseconds.
# Distance Function: distance_dot_cpu, Result: -8390139.120892005, Time: 136.241941 milliseconds.
# Distance Function: distance_dot_cpu, Result: -16776594.641507065, Time: 271.144571 milliseconds.
# L2
# distance_l2_CUPY: [0.2359771728515625, 0.20499229431152344, 0.20765304565429688, 0.20438194274902344, 0.20000457763671875, 0.2032470703125, 0.20058631896972656, 0.2006244659423828, 0.20394325256347656, 0.20536422729492188, 0.2131175994873047, 0.22703170776367188, 0.23697853088378906, 0.27679443359375, 0.2856922149658203, 0.35076141357421875, 0.49415588378906244, 0.6992053985595703, 2.0473575592041016, 3.932523727416992, 7.954931259155273, 16.326265335083008, 32.34907150268555, 64.9547290802002, 129.8473072052002, 256.67643547058105]
# distance_l2_triton: [0.2239990234375, 0.21788597106933594, 0.2092456817626953, 0.2088451385498047, 0.20476341247558594, 0.20804405212402344, 0.20567893981933594, 0.21039962768554688, 0.2093982696533203, 0.21509170532226562, 0.21880149841308594, 0.2345561981201172, 0.2629280090332031, 0.30887603759765625, 0.4253673553466797, 0.5598831176757812, 0.8663654327392578, 1.303567886352539, 2.1300888061523438, 3.8658523559570312, 7.662343978881836, 15.085000991821289, 29.407758712768555, 58.552799224853516, 115.75977325439453, 229.91449356079102]
# distance_l2_cpu: [0.013427734375, 0.01117706298828125, 0.011091232299804688, 0.011854171752929688, 0.011987686157226562, 0.01155853271484375, 0.012712478637695312, 0.014200210571289062, 0.0152587890625, 0.014638900756835938, 0.015306472778320312, 0.018024444580078125, 0.024318695068359375, 0.0537872314453125, 0.08074760437011719, 0.13718605041503906, 0.23120880126953125, 0.4453563690185547, 0.7682228088378906, 1.4026355743408203, 3.2555294036865234, 14.220504760742188, 30.477991104125977, 61.93917274475098, 126.13406181335449, 242.7790069580078]
#
# L1
# distance_manhattan_CUPY: [0.24995803833007815, 0.22040367126464844, 0.22065162658691406, 0.2198505401611328, 0.21958351135253906, 0.22027969360351562, 0.22241592407226562, 0.22406578063964844, 0.2257251739501953, 0.2289581298828125, 0.2357769012451172, 0.2523326873779297, 0.26149749755859375, 0.2811717987060547, 0.3225898742675781, 0.3935432434082031, 0.5069637298583984, 0.6968784332275391, 2.027311325073242, 3.901643753051758, 7.929935455322265, 16.53909683227539, 32.67158508300781, 64.43284034729004, 129.0229320526123, 256.9649028778076]
# distance_l1_triton: [0.18558502197265625, 0.18219947814941406, 0.17969131469726562, 0.17871856689453125, 0.1800537109375, 0.18106460571289062, 0.1781177520751953, 0.1803112030029297, 0.18384933471679688, 0.1869678497314453, 0.1931476593017578, 0.20730018615722656, 0.23200035095214844, 0.28199195861816406, 0.3699302673339844, 0.5453109741210938, 0.8549308776855469, 1.2948131561279297, 2.1195125579833984, 3.78875732421875, 7.375020980834961, 14.859371185302734, 29.512653350830078, 58.27608108520508, 115.3693675994873, 230.41973114013672]
# distance_manhattan_cpu: [0.021638870239257812, 0.01842498779296875, 0.019445419311523438, 0.018405914306640625, 0.019168853759765625, 0.018529891967773438, 0.019273757934570312, 0.019178390502929688, 0.020189285278320312, 0.021724700927734375, 0.021724700927734375, 0.024290084838867188, 0.029458999633789062, 0.04475593566894531, 0.08419990539550781, 0.169525146484375, 0.32952308654785156, 0.6259822845458984, 1.1847972869873047, 2.6865482330322266, 13.733854293823242, 27.173385620117188, 56.28012657165527, 113.59843254089355, 228.56338500976562, 455.7696533203125]
#
# Cosine
# distance_cosine_CUPY: [0.35973548889160156, 0.3436088562011719, 0.3417491912841797, 0.34073829650878906, 0.34584999084472656, 0.34453392028808594, 0.34053802490234375, 0.341796875, 0.3444671630859375, 0.3436565399169922, 0.35180091857910156, 0.37774085998535156, 0.3854846954345703, 0.4166984558105469, 0.4446983337402344, 0.5006599426269531, 0.631561279296875, 0.8230304718017578, 2.0638561248779297, 3.97068977355957, 8.138132095336914, 16.549367904663086, 33.29867362976074, 66.96101188659668, 133.60125541687012, 265.87209701538086]
# distance_cosine_triton: [0.32039642333984375, 0.3120613098144531, 0.30796051025390625, 0.30852317810058594, 0.30951499938964844, 0.3067779541015625, 0.3069019317626953, 0.31014442443847656, 0.3081226348876953, 0.3170204162597656, 0.3220558166503906, 0.3321075439453125, 0.35887718200683594, 0.4102611541748047, 0.49651145935058594, 0.6568527221679688, 0.9833908081054689, 1.4546394348144531, 2.2549057006835938, 3.9526939392089844, 7.69993782043457, 15.02528190612793, 29.917802810668945, 58.636131286621094, 115.89768409729004, 230.20278930664062]
# distance_cosine_cpu: [0.020418167114257812, 0.01964569091796875, 0.018329620361328125, 0.019207000732421875, 0.019884109497070312, 0.0197601318359375, 0.020532608032226562, 0.019931793212890625, 0.021409988403320312, 0.021486282348632812, 0.0238037109375, 0.025911331176757812, 0.036334991455078125, 0.06384849548339844, 0.09042739868164062, 0.1587677001953125, 0.26760101318359375, 0.5028820037841797, 0.9695148468017578, 1.927347183227539, 5.173892974853516, 18.527326583862305, 39.9326229095459, 76.12893104553223, 151.4468002319336, 294.2746162414551]
#
# Dot Product
# distance_dot_CUPY: [0.2235698699951172, 0.2008533477783203, 0.19620895385742188, 0.19567489624023438, 0.2008533477783203, 0.20233154296875, 0.19968032836914062, 0.19872665405273438, 0.2686309814453125, 0.22432327270507812, 0.21286964416503906, 0.2242565155029297, 0.23572921752929688, 0.2574634552001953, 0.2834796905517578, 0.3572273254394531, 0.5111598968505859, 0.7357692718505859, 2.036008834838867, 3.8614749908447266, 7.876091003417969, 16.079654693603516, 31.681737899780273, 63.56873512268066, 126.81050300598146, 252.36393928527835]
# distance_dot_triton: [0.20994186401367188, 0.1964855194091797, 0.1973438262939453, 0.19736289978027344, 0.19834518432617188, 0.19618988037109375, 0.19842147827148438, 0.19830703735351562, 0.2070903778076172, 0.2065277099609375, 0.21323204040527344, 0.2259540557861328, 0.2514171600341797, 0.2987098693847656, 0.3883552551269531, 0.5575847625732422, 0.8900165557861328, 1.3811779022216797, 2.146120071411133, 3.8026809692382812, 7.365512847900391, 14.941225051879883, 29.375953674316406, 58.08237075805664, 115.47009468078613, 230.3676700592041]
# distance_dot_cpu: [0.01735687255859375, 0.017642974853515625, 0.01667022705078125, 0.017566680908203125, 0.016698837280273438, 0.017385482788085938, 0.0168609619140625, 0.017518997192382812, 0.024404525756835938, 0.014963150024414062, 0.0140380859375, 0.016431808471679688, 0.019273757934570312, 0.029239654541015625, 0.04775047302246094, 0.10324478149414062, 0.21539688110351562, 0.41464805603027344, 0.7978534698486328, 1.690521240234375, 4.67097282409668, 15.385608673095703, 31.768970489501953, 67.06491470336914, 136.24194145202637, 271.1445713043213]

# %%
# #Print four graphs: Each graph should have 3 lines CUPY, Triton, CPU
# #Graph should be in log-log scale but the x-axis should be power of 2
# #Plotting the results
# import matplotlib.pyplot as plt
# def plot_results(results_list):
#     for function_type, function_list in results_list.items():
#         plt.figure()
#         for function in function_list:
#             for function_name, result in function.items():
#                 plt.plot(vector_sizes, result, label=function_name)
#         plt.xscale('log', base=2)
#         plt.yscale('log')
#         plt.xlabel('Vector Size')
#         plt.ylabel('Time (s)')
#         plt.title(function_type)
#         plt.legend()
#         plt.show()
# plot_results(results_list)
# #Plotting the results

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

# Set a modern seaborn style
sns.set_theme(style="whitegrid", font_scale=1.2)

# Optional: use a specific color palette
colors = sns.color_palette("colorblind")  # good for accessibility

def plot_results(results_list):
    for idx, (function_type, function_list) in enumerate(results_list.items()):
        plt.figure(figsize=(8, 7.5))  # bigger, cleaner layout

        color_idx = 0
        for function in function_list:
            for function_name, result in function.items():
                plt.plot(
                    vector_sizes,
                    result,
                    label=function_name.replace('_', ' ').upper(),
                    color=colors[color_idx % len(colors)],
                    linewidth=2.5,
                    marker='o',
                    markersize=5,
                )
                color_idx += 1

        plt.xscale('log', base=2)
        plt.yscale('log')

        # Log ticks with base-2 labels
        plt.gca().xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f"$2^{{{int(np.log2(x))}}}$"))

        plt.xlabel("Vector Size (log scale)", labelpad=10)
        plt.ylabel("Time (s) (log scale, descending)", labelpad=10)
        plt.gca().invert_yaxis() 
        plt.title(f"Average time to compute {function_type} distance between two random vectors", fontsize=16, weight="bold")

        plt.legend(title="Implementation", loc="best", frameon=True)
        plt.tight_layout()
        plt.grid(True, which='both', linestyle='--', linewidth=0.5)
                # Add caption below the plot
        plt.figtext(
            0.5, -0.12,
            "In the case of the GPU accelerated libraries, these timings are inclusive of the memory transfer in the GPU. "
            "As we can see here, CPU performance is better at lower dimensions and scales similarly with CuPy and Triton as the memory increases.\n\n"
            "We note here that this is because there is only one distance calculation being carried out and, despite parallelising across segments within the vectors "
            "and reducing these partial sums, the memory overhead involved means that there is no significant benefit from utilizing the GPU for a single distance calculation.",
            wrap=True,
            ha="center",
            fontsize=10
        )
        plt.show()
plot_results(results_list)
